# %%
import pandas as pd
finance = pd.read_csv("C:/UBCO/DATA_301/project-group44-project-1/data/processed/Data.csv")
finance
# Out:
#           Date  Unnamed: 1  Bank rate  \
# 0     3-Jan-18         NaN       1.25
# 1    10-Jan-18         NaN       1.25
# 2    17-Jan-18         NaN       1.50
# 3    24-Jan-18         NaN       1.50
# 4    31-Jan-18         NaN       1.50
# ..         ...         ...        ...
# 190  25-Aug-21         NaN       0.50
# 191   1-Sep-21         NaN       0.50
# 192   8-Sep-21         NaN       0.50
# 193  15-Sep-21         NaN       0.50
# 194  22-Sep-21         NaN       0.50
#
#      Chartered bank administered interest rates - Prime rate 1  \
# 0                                                 3.20
# 1                                                 3.20
# 2                                                 3.20
# 3                                                 3.45
# 4                                                 3.45
# ..                                                 ...
# 190                                               2.45
# ...

# %%
import numpy as np
df = finance
df[df ==".."] = np.nan
df[df =="..t"] = np.nan
df_cleaned = df.dropna(axis=0)
df_cleaned = df_cleaned.T
df_cleaned
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
import project_functions1 as p1
df1 = p1.load_and_process("C:/UBCO/DATA_301/project-group44-project-1/data/processed/Data.csv")
df1
df1.plot("Date","Bank rate")
df1.plot("Date","Chartered bank administered interest rates - Prime rate 1")
df1.plot("Date","Selected Government of Canada benchmark bond yields: 2 year")
df1.plot("Date","Government of Canada marketable bonds, average yield: 1-3 year 6")
df1.plot("Date","Chartered banks - 90 day term deposits 1")
df1.plot("Date","Treasury Bills: 1 month")
df1.plot("Date","Real return bonds, long-term")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# C:\Users\YUTING~1\AppData\Local\Temp/ipykernel_23060/3031688076.py in <module>
# ----> 1 from .. import project_functions1 as p1
#       2 df1 = p1.load_and_process("C:/UBCO/DATA_301/project-group44-project-1/data/processed/Data.csv")
#       3 df1
#       4 df1.plot("Date","Bank rate")
#       5 df1.plot("Date","Chartered bank administered interest rates - Prime rate 1")
#
# ImportError: attempted relative import with no known parent package

# %%
df = pd.read_csv("../../data/processed/Data.csv")

# %%
import project_functions1 as p1
df1 = p1.load_and_process("../data/processed/Data.csv")
df1
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# C:\Users\YUTING~1\AppData\Local\Temp/ipykernel_12952/3497565483.py in <module>
# ----> 1 import project_functions1 as p1
#       2 df1 = p1.load_and_process("../data/processed/Data.csv")
#       3 df1
#
# ModuleNotFoundError: No module named 'project_functions1'
